# %% [markdown]
# **Name: Kausik Amancherla**
#
# **Student ID: 002544017**

# %% [markdown]
# 1. Write a piece of code using a regular expression in Python to count how many times the following name appears: CICERO, this regex needs to be case-sensitive. (10 points)

# %%
import os.path
with open("/content/sample_data/hw_1-text.txt", "r") as fp:
    document = fp.read()

# %%
word_C = re.compile('CICERO')
matchtheletter =  word_C.findall(document)
len(matchtheletter)
# Out:
# 7

# %% [markdown]
# 2. Write a regular expression in Python that finds all 6 character words found in this play. (10 points)

# %%
sixletter=re.compile(r'\b\w{6}\b')
matching=sixletter.findall(document)
matching
# Out:
# ['Julius',
#  'Caesar',
#  'street',
#  'Second',
#  'answer',
#  'Second',
#  'indeed',
#  'mender',
#  'Second',
#  'fellow',
#  'Second',
#  'cobble',
#  'Second',
#  'meddle',
#  'indeed',
#  'danger',
#  'proper',
#  'Second',
#  'myself',
#  'indeed',
#  'Caesar',
#  'brings',
#  'follow',
#  'wheels',
#  'blocks',
#  'stones',
#  'things',
#  'hearts',
#  'Pompey',
#  'towers',
#  'Pompey',
#  'appear',
#  'sounds',
#  'shores',
#  'attire',
#  'Pompey',
#  'houses',
#  'plague',
#  'lowest',
#  'stream',
#  'shores',
#  'Exeunt',
#  'basest',
#  'vanish',
#  'tongue',
#  'images',
#  'matter',
#  'images',
#  'Caesar',
#  'vulgar',
#  'Caesar',
#  'Exeunt',
#  'public',
#  'CAESAR',
#  'ANTONY',
#  'course',
#  'PORTIA',
#  'DECIUS',
#  'BRUTUS',
#  'CICERO',
#  'BRUTUS',
#  'CAESAR',
#  'Caesar',
#  'speaks',
#  'CAESAR',
#  'CAESAR',
#  'course',
#  'ANTONY',
#  'Caesar',
#  'CAESAR',
#  'Forget',
#  'elders',
#  'barren',
#  'ANTONY',
#  'Caesar',
#  'CAESAR',
# ...

# %%
print("There are" ,len(matching),"six letter words")
# Out:
# There are 2295 six letter words

# %% [markdown]
# 3. Write a piece of code that uses a regular expression in Python to count how many words are capitalized in the first letter only. (20 points)

# %%
capitalization = re.compile(r'\b[A-Z][a-z]+\b')
matching2 = pattern3.findall(document)
matching2
# Out:
# ['The',
#  'Life',
#  'Death',
#  'Julius',
#  'Caesar',
#  'Rome',
#  'Enter',
#  'Commoners',
#  'Hence',
#  'Is',
#  'Being',
#  'Upon',
#  'Of',
#  'Speak',
#  'First',
#  'Commoner',
#  'Why',
#  'Where',
#  'What',
#  'You',
#  'Second',
#  'Commoner',
#  'Truly',
#  'But',
#  'Second',
#  'Commoner',
#  'What',
#  'Second',
#  'Commoner',
#  'Nay',
#  'What',
#  'Second',
#  'Commoner',
#  'Why',
#  'Thou',
#  'Second',
#  'Commoner',
#  'Truly',
#  'As',
#  'But',
#  'Why',
#  'Second',
#  'Commoner',
#  'Truly',
#  'But',
#  'Caesar',
#  'Wherefore',
#  'What',
#  'What',
#  'Rome',
#  'To',
#  'You',
#  'Rome',
#  'Knew',
#  'Pompey',
#  'Many',
#  'Have',
#  'To',
#  'Your',
#  'The',
#  'To',
#  'Pompey',
#  'Rome',
#  'And',
#  'Have',
#  'That',
#  'Tiber',
#  'To',
#  'Made',
#  'And',
#  'And',
#  'And',
#  'That',
#  'Pompey',
#  'Be',
#  'Run',
#  'Pray',
#  'That',
#  'Go',
#  'Assemble',
#  'Draw',
#  'Tiber',
#  'Into',
#  'Do',
#  'Exeunt',
#  'Commoners',
# ...

# %%
print("There are" ,len(matching2),"words that are capitalized in the first letter only")
# Out:
# There are 3737 words that are capitalized in the first letter only

# %% [markdown]
# 4. Write a regular expression using groups in Python that extracts all phrases that have “son of ” and extract/output the answer in a case-insensitive way. For example, for the following “I am the son of earth”, should find “son of earth” and extract/output “earth”. (20 points)

# %%
sonof = re.compile(r'(\bson of (.*)\b)')
matching3 = sonof.findall(document)
for item in matching3:
  print(item[1])
# Out:
# Rome
# Caesar
# Marcus Cato, ho
# Marcus Cato, ho

# %% [markdown]
# 5. Plays are divided in acts, write a regular expression using groups in Python that extracts the number of each act found in this play in a case-sensitive way. (20 points)

# %%
acts = re.compile(r'(ACT)(\b.*\b)')
matching4 = acts.findall(document)
for item in matching4:
  print(item[1])
# Out:
#  I
#  II
#  III
#  IV
#  V

# %% [markdown]
# 6. Write a Python function that takes the file as an input and outputs how many lines end with: ? , that is a question mark at the end of the line. This function needs to use a regular expression. (20 points)

# %%
def question_function(f_name):
    with open(f_name, 'r') as fp:
        txt = fp.read()
    return len(re.findall(r'\?$', txt, re.M))

# %%
print(question_function(r"/content/sample_data/hw_1-text.txt"),"sentences in the file end with '?'",)
# Out:
# 215 sentences in the file end with '?'

# %% [markdown]
# 7. Using the code from Class 04, train a Random Forest classification model for the same two newsgroups, generate the confusion matrix, and all the same performance metrics. (50 points)

# %%
from sklearn.datasets import fetch_20newsgroups

data = fetch_20newsgroups()
data.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
categories = ['rec.autos','comp.graphics']
train = fetch_20newsgroups(subset='train', categories=categories)
test = fetch_20newsgroups(subset='test', categories=categories)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
model = make_pipeline(CountVectorizer(), RandomForestClassifier())
model.fit(train.data, train.target)
labels = model.predict(test.data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
mat = confusion_matrix(test.target, labels)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=train.target_names, yticklabels=train.target_names)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
import sklearn
import numpy as np
print('Accuracy:', sklearn.metrics.accuracy_score(test.target,labels))
print('Precision:', sklearn.metrics.precision_score(test.target,labels))
print('Recall:', sklearn.metrics.recall_score(test.target,labels))
print('F1 Score:', sklearn.metrics.f1_score(labels, test.target, average='macro'))
print('Mean Absolute Error:', sklearn.metrics.mean_absolute_error(test.target,labels))
print('Mean Squared Error:', sklearn.metrics.mean_squared_error(test.target, labels))  
print('Root Mean Squared Error:', np.sqrt(sklearn.metrics.mean_squared_error(test.target, labels)))
# Out:
# Accuracy: 0.9235668789808917
# Precision: 0.9375
# Recall: 0.9090909090909091
# F1 Score: 0.9235637779941577
# Mean Absolute Error: 0.07643312101910828
# Mean Squared Error: 0.07643312101910828
# Root Mean Squared Error: 0.2764654065504548

# %% [markdown]
# Bonus (15 points): Using the code from Class 04. Write a function to find the best performing model for the TF-IDF vectorization. The requirements for this are:

# %% [markdown]
# Naive Bayes - TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
model_NB = make_pipeline(TfidfVectorizer(), MultinomialNB())
model_NB.fit(train.data, train.target)
labels_NB = model_NB.predict(test.data)

# %%
import sklearn
print('Accuracy:', sklearn.metrics.accuracy_score(test.target,labels_NB))
print('F1 Score:', sklearn.metrics.f1_score(labels_NB, test.target, average='macro'))
# Out:
# Accuracy: 0.9477707006369427
# F1 Score: 0.9476207603086282

# %% [markdown]
# Perceptron - TF-IDF

# %%
from sklearn.linear_model import Perceptron
model_P = make_pipeline(TfidfVectorizer(), Perceptron())
model_P.fit(train.data, train.target)
labels_P = model_P.predict(test.data)

# %%
 import sklearn
import sklearn
print('Accuracy:', sklearn.metrics.accuracy_score(test.target,labels_P))
print('F1 Score:', sklearn.metrics.f1_score(labels_P, test.target, average='macro'))
# Out:
# Accuracy: 0.9490445859872612
# F1 Score: 0.9489928525016245

# %% [markdown]
# Logistic Regression - TF-IDF

# %%
from sklearn.linear_model import LogisticRegression
model_LR = make_pipeline(TfidfVectorizer(), LogisticRegression())
model_LR.fit(train.data, train.target)
labels_LR = model_LR.predict(test.data)

# %%
import sklearn
print('Accuracy:', sklearn.metrics.accuracy_score(test.target,labels_LR))
print('F1 Score:', sklearn.metrics.f1_score(labels_LR, test.target, average='macro'))
# Out:
# Accuracy: 0.954140127388535
# F1 Score: 0.9541311207198785

# %% [markdown]
# Decision Tree - TF-IDF

# %%
from sklearn.tree import DecisionTreeClassifier
model_D = make_pipeline(TfidfVectorizer(), DecisionTreeClassifier())
model_D.fit(train.data, train.target)
labels_D = model_D.predict(test.data)

# %%
import sklearn
print('Accuracy:', sklearn.metrics.accuracy_score(test.target,labels_D))
print('F1 Score:', sklearn.metrics.f1_score(labels_D, test.target, average='macro'))
# Out:
# Accuracy: 0.89171974522293
# F1 Score: 0.8917190423565572

# %% [markdown]
# 1) Pass all metrics for each model in a single dataframe (each row has a metric value, each column is a model type).

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
 Prf_data = [(sklearn.metrics.f1_score(labels_NB, test.target, average='macro'), sklearn.metrics.f1_score(labels_P, test.target, average='macro'), sklearn.metrics.f1_score(labels_LR, test.target, average='macro'), sklearn.metrics.f1_score(labels_D, test.target, average='macro'), sklearn.metrics.f1_score(labels, test.target, average='macro')),
             (sklearn.metrics.accuracy_score(test.target,labels_NB),sklearn.metrics.accuracy_score(test.target,labels_P),sklearn.metrics.accuracy_score(test.target,labels_LR),sklearn.metrics.accuracy_score(test.target,labels_D),sklearn.metrics.accuracy_score(test.target,labels)),
            (sklearn.metrics.precision_score(test.target,labels_NB),sklearn.metrics.precision_score(test.target,labels_P),sklearn.metrics.precision_score(test.target,labels_LR),sklearn.metrics.precision_score(test.target,labels_D),sklearn.metrics.precision_score(test.target,labels)),
            (sklearn.metrics.recall_score(test.target,labels_NB),sklearn.metrics.recall_score(test.target,labels_P),sklearn.metrics.recall_score(test.target,labels_LR),sklearn.metrics.recall_score(test.target,labels_D),sklearn.metrics.recall_score(test.target,labels)),
            (sklearn.metrics.mean_absolute_error(test.target,labels_NB),sklearn.metrics.mean_absolute_error(test.target,labels_P),sklearn.metrics.mean_absolute_error(test.target,labels_LR),sklearn.metrics.mean_absolute_error(test.target,labels_D),sklearn.metrics.mean_absolute_error(test.target,labels)),
            (sklearn.metrics.mean_squared_error(test.target, labels_NB),sklearn.metrics.mean_squared_error(test.target, labels_P),sklearn.metrics.mean_squared_error(test.target, labels_LR),sklearn.metrics.mean_squared_error(test.target, labels_D),sklearn.metrics.mean_squared_error(test.target, labels)),
            (np.sqrt(sklearn.metrics.mean_squared_error(test.target, labels_NB)),np.sqrt(sklearn.metrics.mean_squared_error(test.target, labels_P)),np.sqrt(sklearn.metrics.mean_squared_error(test.target, labels_LR)),np.sqrt(sklearn.metrics.mean_squared_error(test.target, labels_D)),np.sqrt(sklearn.metrics.mean_squared_error(test.target, labels)))]

# %%
import pandas as pd

performance_df = pd.DataFrame(Prf_data,columns = ['Multinomial Naive Bayes','Perceptron','Logistic Regression','Decision Tree','Random Forest Classifier'],index =['F1_Score','Accuracy','Precision', 'Recall', 'Mean Absolute Error', 'Mean Squared Error','Root Mean Squared Error'])

# %%
performance_df
# Out:
#                          Multinomial Naive Bayes  ...  Random Forest Classifier
# F1_Score                                0.947621  ...                  0.923564
# Accuracy                                0.947771  ...                  0.923567
# Precision                               0.911833  ...                  0.937500
# Recall                                  0.992424  ...                  0.909091
# Mean Absolute Error                     0.052229  ...                  0.076433
# Mean Squared Error                      0.052229  ...                  0.076433
# Root Mean Squared Error                 0.228537  ...                  0.276465
#
# [7 rows x 5 columns]

# %% [markdown]
# 2) Make the decision of the best model by counting which column has the highest F1-score and accuracy.

# %%
def Best_Performing_Model(performance_df):
  Best_Model = performance_df.sort_values(by=['F1_Score','Accuracy'], ascending=False,inplace= False,axis = 1).columns[0]
  return Best_Model

# %%
print("Best Model: ",Best_Performing_Model(performance_df))
# Out:
# Best Model:  Logistic Regression
